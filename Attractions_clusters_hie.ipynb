# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np
from decimal import *
import MySQLdb
import pandas.io.sql as psql
from MySQLdb.converters import conversions
from MySQLdb.constants import FIELD_TYPE
import matplotlib.pyplot as plt
# %pylab inline
# %matplotlib inline
from math import radians, sin, cos, sqrt, asin, pi, degrees
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn import cluster
import json
import scraperwiki
import scraperwiki
import json
import datetime
import keys
import re



def GetRecentCrimeParsed(lon,lat,radius):
  "imports recent crimes from the specified location"
  url = "http://api.spotcrime.com/crimes.json?lat="+str(lat)+"&lon="+str(lon)+"&radius="+str(radius)+keys.spotcrime_secret
  s = scraperwiki.scrape(url)
  parsed_json = json.loads(s.partition('(')[-1].rpartition(')')[0])
  return parsed_json

def GetRecentCrimeString(lon,lat,radius):
  "imports recent crimes from the specified location"
  url = "http://api.spotcrime.com/crimes.json?lat="+str(lat)+"&lon="+str(lon)+"&radius="+str(radius)+keys.spotcrime_secret
  s = scraperwiki.scrape(url)
  return (s.partition('(')[-1].rpartition(')')[0])

def WriteRecentCrimes(start,step):
    filename="recent_crimes_json_"+str(start)+"_"+str(start+step)+".txt"
    with open(filename,"a") as myfile:
        myfile.write("[")
        myfile.write('{"eanid":'+str(df.ix[start].EANHotelID)+","+
            GetRecentCrimeString(df.ix[start].Longitude,df.ix[start].Latitude,radius)[1:]+'\n')
        for index, row in df[1:].iterrows():
            myfile.write(',{"eanid":'+str(row.EANHotelID)+","+
                         GetRecentCrimeString(row.Longitude,row.Latitude,radius)[1:]+'\n')
        myfile.write("]")
    return filename

def ViolentCrimeCount(lon,lat,radius):
  crime_json=GetRecentCrimeParsed(lon=lon,lat=lat,radius=radius)
  crime_list=[]
  for crime in crime_json['crimes']:
      crime_dict={'Date': 'no date','Assault': 0, 'Burglary': 0, 'Other': 0, 'Theft': 0, 'Vandalism': 0,
                  'Arrest': 0, 'Arson': 0, 'Robbery': 0, 'Shooting':0}
      crime_dict[crime['type']] = crime_dict.get(crime['type'], 0) + 1
      crime_dict['Date'] = datetime.datetime.strptime((crime['date'])[0:8], "%m/%d/%y").date()
      crime_list.append(crime_dict)
  try:
      testdf=DataFrame(crime_list)
      testdf=testdf.groupby(by=testdf.Date).sum()
      violent_list=['Arrest','Arson','Assault','Shooting','Robbery','Vandalism']
      count=0
      for crime in violent_list:
        count += testdf[crime].sum()
  except:
      count=0
  return count



conversions[FIELD_TYPE.DECIMAL] = float
conversions[FIELD_TYPE.NEWDECIMAL] = float

conn = MySQLdb.connect(user="root", host="localhost", db='eanprod', charset='utf8',unix_socket="/tmp/mysql.sock")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['radians', 'colors', 'cos', 'degrees', 'sqrt', 'pi', 'sin']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ## Select attractions and give them better categories

# %%
sql='SELECT * FROM pointsofinterestcoordinateslist WHERE RegionNameLong LIKE "%California, United States of America%";'
attractions = DataFrame(psql.read_sql(sql, conn))

attractions.SubClassification[attractions.SubClassification=='anchor']='marine'
attractions.SubClassification[attractions.SubClassification=='tree']='park'
attractions.SubClassification[attractions.SubClassification=='icecream']='amusement'
attractions.SubClassification[attractions.SubClassification=='sunglass']='beach'
attractions.SubClassification[attractions.SubClassification=='civic']='cityscape'
attractions.SubClassification[attractions.SubClassification=='stadius']='sports'
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 3956 # Radius of earth 
    # Use 3956 for miles, 6371 for kilometers
    return c * r

# %% [markdown]
# ## compute distance matrix

# %%
X=attractions[:][['Latitude', 'Longitude']].values
N = X.shape[0]
distance_matrix = zeros((N, N))
for i in xrange(N):
    for j in xrange(i):
        lati, loni = X[i]
        latj, lonj = X[j]
        distance_matrix[i, j] = haversine(loni, lati, lonj, latj)
        distance_matrix[j, i] = distance_matrix[i, j]

# %% [markdown]
# ## compute DBSCAN clusters

# %%
dbsc = DBSCAN(eps=1., min_samples=1,metric='precomputed').fit(distance_matrix)
core_samples_mask = np.zeros_like(dbsc.labels_, dtype=bool)
core_samples_mask[dbsc.core_sample_indices_] = True
labels = dbsc.labels_
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
unique_labels = set(labels)
colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_labels)))
plt.figure(figsize=(8, 8))
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = 'k'

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 1], xy[:, 0], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 1], xy[:, 0], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=6)
    
plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()

# %%
# Out:
# 1372

# %%
from __future__ import print_function

from bokeh.browserlib import view
from bokeh.document import Document
from bokeh.embed import file_html
from bokeh.models.glyphs import Circle
from bokeh.models import (
    GMapPlot, Range1d, ColumnDataSource,
    PanTool, WheelZoomTool, BoxSelectTool,
    BoxSelectionOverlay, GMapOptions)
from bokeh.resources import INLINE

x_range = Range1d()
y_range = Range1d()

# JSON style string taken from: https://snazzymaps.com/style/1/pale-dawn
map_options = GMapOptions(lat=37.2861, lng=-119.7394, map_type="roadmap", zoom=6, styles="""
[{"featureType":"administrative","elementType":"all","stylers":[{"visibility":"on"},{"lightness":33}]},{"featureType":"landscape","elementType":"all","stylers":[{"color":"#f2e5d4"}]},{"featureType":"poi.park","elementType":"geometry","stylers":[{"color":"#c5dac6"}]},{"featureType":"poi.park","elementType":"labels","stylers":[{"visibility":"on"},{"lightness":20}]},{"featureType":"road","elementType":"all","stylers":[{"lightness":20}]},{"featureType":"road.highway","elementType":"geometry","stylers":[{"color":"#c5c6c6"}]},{"featureType":"road.arterial","elementType":"geometry","stylers":[{"color":"#e4d7c6"}]},{"featureType":"road.local","elementType":"geometry","stylers":[{"color":"#fbfaf7"}]},{"featureType":"water","elementType":"all","stylers":[{"visibility":"on"},{"color":"#acbcc9"}]}]
""")

plot = GMapPlot(
    x_range=x_range, y_range=y_range,
    map_options=map_options,
    title="California: big clusters"
)
lat=list(X[:,0])
lon=list(X[:,1])
cluster_nn=labels
num_objects=[3,5,1]
fill=['red', 'blue', 'orange']
colors = [
    "#%02x%02x%02x" % (np.floor(50+25*r), np.floor(20+30*g), 200) for r,g in zip(cluster_nn,cluster_nn)
]
fill=colors
source = ColumnDataSource(
    data=dict(
        lat=lat,
        lon=lon,
        fill=fill
    )
)
# colors = ["#%02x%02x%02x" % (r, g, 150) for r, g in zip(np.floor(50+2*x), np.floor(30+2*y))]
circle = Circle(x="lon", y="lat", size=15, fill_color="fill", line_color="black")
plot.add_glyph(source, circle)

pan = PanTool()
wheel_zoom = WheelZoomTool()
box_select = BoxSelectTool()

plot.add_tools(pan, wheel_zoom, box_select)
overlay = BoxSelectionOverlay(tool=box_select)
plot.add_layout(overlay)

doc = Document()
doc.add(plot)

if __name__ == "__main__":
    filename = "maps.html"
    with open(filename, "w") as f:
        f.write(file_html(doc, INLINE, "Cali_big_clust"))
    print("Wrote %s" % filename)
    view(filename)
# Out:
# Wrote maps.html

# %% [markdown]
# ## break big clusters into smaller pieces

# %%
import scipy.spatial.distance as ssd
from scipy.cluster.hierarchy import fcluster,linkage

max_d=2
clusters_df = pd.DataFrame(columns=['ClusterNum','Latitude','Longitude'])
new_label=0
label_copy=numpy.empty_like(labels)
for cluster_num in unique_labels:
    X_c=X[labels==cluster_num]
    N_c = X_c.shape[0]
    if N_c>1:
        distArray = ssd.squareform(distance_matrix[labels==cluster_num][:,labels==cluster_num])
        Z1=linkage(distArray,method='complete')
        clusters = fcluster(Z1, max_d, criterion='distance')
        label_copy[labels==cluster_num]=(clusters-1)+new_label
    else:
        clusters=[1]
        label_copy[labels==cluster_num]=new_label
    new_label+=len(unique(clusters)-1)

for i in range(label_copy.min(), label_copy.max()+1):
    center=X[label_copy == i].mean(0)
    clusters_df=clusters_df.append({'ClusterNum':i,
                                        'Latitude':center[0],
                                        'Longitude':center[1]},ignore_index=True)

# %%
n_clusters_ = len(set(label_copy))
unique_labels_copy = set(label_copy)
colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_labels_copy)))
plt.figure(figsize=(8, 8))
for k, col in zip(unique_labels_copy, colors):
    class_member_mask = (label_copy == k)
    xy = X[class_member_mask]
    plt.plot(xy[:, 1], xy[:, 0], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)
    
plt.title('California Attractions Clusters')
plt.show()

# %%
x_range = Range1d()
y_range = Range1d()

# JSON style string taken from: https://snazzymaps.com/style/1/pale-dawn
map_options = GMapOptions(lat=37.2861, lng=-119.7394, map_type="roadmap", zoom=6, styles="""
[{"featureType":"administrative","elementType":"all","stylers":[{"visibility":"on"},{"lightness":33}]},{"featureType":"landscape","elementType":"all","stylers":[{"color":"#f2e5d4"}]},{"featureType":"poi.park","elementType":"geometry","stylers":[{"color":"#c5dac6"}]},{"featureType":"poi.park","elementType":"labels","stylers":[{"visibility":"on"},{"lightness":20}]},{"featureType":"road","elementType":"all","stylers":[{"lightness":20}]},{"featureType":"road.highway","elementType":"geometry","stylers":[{"color":"#c5c6c6"}]},{"featureType":"road.arterial","elementType":"geometry","stylers":[{"color":"#e4d7c6"}]},{"featureType":"road.local","elementType":"geometry","stylers":[{"color":"#fbfaf7"}]},{"featureType":"water","elementType":"all","stylers":[{"visibility":"on"},{"color":"#acbcc9"}]}]
""")

plot = GMapPlot(
    x_range=x_range, y_range=y_range,
    map_options=map_options,
    title="California: small clusters"
)
lat=list(X[:,0])
lon=list(X[:,1])
cluster_nn=labels
num_objects=[3,5,1]
fill=['red', 'blue', 'orange']
colors = [
    "#%02x%02x%02x" % (np.floor(50+25*r), np.floor(20+30*g), 200) for r,g in zip(cluster_nn,cluster_nn)
]
fill=colors
source = ColumnDataSource(
    data=dict(
        lat=lat,
        lon=lon,
        fill=fill
    )
)
# colors = ["#%02x%02x%02x" % (r, g, 150) for r, g in zip(np.floor(50+2*x), np.floor(30+2*y))]
circle = Circle(x="lon", y="lat", size=15, fill_color="fill", line_color="black")
plot.add_glyph(source, circle)

pan = PanTool()
wheel_zoom = WheelZoomTool()
box_select = BoxSelectTool()

plot.add_tools(pan, wheel_zoom, box_select)
overlay = BoxSelectionOverlay(tool=box_select)
plot.add_layout(overlay)

doc = Document()
doc.add(plot)

if __name__ == "__main__":
    filename = "maps.html"
    with open(filename, "w") as f:
        f.write(file_html(doc, INLINE, "Cali_big_clust"))
    print("Wrote %s" % filename)
    view(filename)
# Out:
# Wrote maps.html

# %%
attractions['ClusterNum'] = label_copy.tolist()
pattern = re.compile(r'\, (.+?)\, California, United States', flags=re.DOTALL)
attractions['City']=attractions.apply(lambda row: pattern.findall(row.RegionNameLong)[0], axis=1)
clusters_df['City']=clusters_df.apply(lambda row: (attractions.City[attractions.ClusterNum==row.ClusterNum]).max(), axis=1)

# %% [markdown]
# get wikipedia links for attractions

# %%
import wikipedia

def GetWikiUrl(lat,lon,title):
    results = wikipedia.geosearch(latitude=lat, longitude=lon, 
                                    title=title,results=10, radius=100)
    if len(results)>0:
        try:
            return wikipedia.page(results).url
        except:
            return ''
    else:
        return ''

attractions['Wiki']=attractions.apply(lambda row: GetWikiUrl(lon=row.Longitude,
                                                               lat=row.Latitude,
                                                               title=row.RegionName), axis=1)
# Out:
# /usr/local/lib/python2.7/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-30-34176fdfb73a> in <module>()
#      14 attractions['Wiki']=attractions.apply(lambda row: GetWikiUrl(lon=row.Longitude,
#      15                                                                lat=row.Latitude,
# ---> 16                                                                title=row.RegionName), axis=1)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    3716                     if reduce is None:
#    3717                         reduce = True
# -> 3718                     return self._apply_standard(f, axis, reduce=reduce)
#    3719             else:
#    3720                 return self._apply_broadcast(f, axis)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    3806             try:
#    3807                 for i, v in enumerate(series_gen):
# -> 3808                     results[i] = func(v)
#    3809                     keys.append(v.name)
#    3810             except Exception as e:
#
# <ipython-input-30-34176fdfb73a> in <lambda>(row)
#      14 attractions['Wiki']=attractions.apply(lambda row: GetWikiUrl(lon=row.Longitude,
#      15                                                                lat=row.Latitude,
# ---> 16                                                                title=row.RegionName), axis=1)
#
# <ipython-input-30-34176fdfb73a> in GetWikiUrl(lat, lon, title)
#       3 def GetWikiUrl(lat,lon,title):
#       4     results = wikipedia.geosearch(latitude=lat, longitude=lon,
# ----> 5                                     title=title,results=10, radius=100)
#       6     if len(results)>0:
#       7         try:
#
# /usr/local/lib/python2.7/site-packages/wikipedia/util.pyc in __call__(self, *args, **kwargs)
#      26       ret = self._cache[key]
#      27     else:
# ---> 28       ret = self._cache[key] = self.fn(*args, **kwargs)
#      29
#      30     return ret
#
# /usr/local/lib/python2.7/site-packages/wikipedia/wikipedia.pyc in geosearch(latitude, longitude, title, results, radius)
#     147     search_params['titles'] = title
#     148
# --> 149   raw_results = _wiki_request(search_params)
#     150
#     151   if 'error' in raw_results:
#
# /usr/local/lib/python2.7/site-packages/wikipedia/wikipedia.pyc in _wiki_request(params)
#     740     RATE_LIMIT_LAST_CALL = datetime.now()
#     741
# --> 742   return r.json()
#
# /usr/local/lib/python2.7/site-packages/requests/models.pyc in json(self, **kwargs)
#     817                     # used.
#     818                     pass
# --> 819         return json.loads(self.text, **kwargs)
#     820
#     821     @property
#
# /usr/local/lib/python2.7/site-packages/simplejson/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     514             parse_constant is None and object_pairs_hook is None
#     515             and not use_decimal and not kw):
# --> 516         return _default_decoder.decode(s)
#     517     if cls is None:
#     518         cls = JSONDecoder
#
# /usr/local/lib/python2.7/site-packages/simplejson/decoder.pyc in decode(self, s, _w, _PY3)
#     368         if _PY3 and isinstance(s, binary_type):
#     369             s = s.decode(self.encoding)
# --> 370         obj, end = self.raw_decode(s)
#     371         end = _w(s, end).end()
#     372         if end != len(s):
#
# /usr/local/lib/python2.7/site-packages/simplejson/decoder.pyc in raw_decode(self, s, idx, _w, _PY3)
#     398             elif ord0 == 0xef and s[idx:idx + 3] == '\xef\xbb\xbf':
#     399                 idx += 3
# --> 400         return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: ('Expecting value: line 1 column 1 (char 0)', u'occurred at index 1204')

# %%
attractions['Crime']=attractions.apply(lambda row: ViolentCrimeCount(lon=row.Longitude,
                                                               lat=row.Latitude,
                                                               radius=0.5), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-3caa580333db> in <module>()
#       1 attractions['Crime']=attractions.apply(lambda row: ViolentCrimeCount(lon=row.Longitude,
#       2                                                                lat=row.Latitude,
# ----> 3                                                                radius=0.5), axis=1)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    3716                     if reduce is None:
#    3717                         reduce = True
# -> 3718                     return self._apply_standard(f, axis, reduce=reduce)
#    3719             else:
#    3720                 return self._apply_broadcast(f, axis)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    3806             try:
#    3807                 for i, v in enumerate(series_gen):
# -> 3808                     results[i] = func(v)
#    3809                     keys.append(v.name)
#    3810             except Exception as e:
#
# <ipython-input-34-3caa580333db> in <lambda>(row)
#       1 attractions['Crime']=attractions.apply(lambda row: ViolentCrimeCount(lon=row.Longitude,
#       2                                                                lat=row.Latitude,
# ----> 3                                                                radius=0.5), axis=1)
#
# <ipython-input-15-92fd497e1da8> in ViolentCrimeCount(lon, lat, radius)
#      51
#      52 def ViolentCrimeCount(lon,lat,radius):
# ---> 53   crime_json=GetRecentCrimeParsed(lon=lon,lat=lat,radius=radius)
#      54   crime_list=[]
#      55   for crime in crime_json['crimes']:
#
# <ipython-input-15-92fd497e1da8> in GetRecentCrimeParsed(lon, lat, radius)
#      28   "imports recent crimes from the specified location"
#      29   url = "http://api.spotcrime.com/crimes.json?lat="+str(lat)+"&lon="+str(lon)+"&radius="+str(radius)+keys.spotcrime_secret
# ---> 30   s = scraperwiki.scrape(url)
#      31   parsed_json = json.loads(s.partition('(')[-1].rpartition(')')[0])
#      32   return parsed_json
#
# /usr/local/lib/python2.7/site-packages/scraperwiki/utils.pyc in scrape(url, params, user_agent)
#      32     data = params and six.moves.urllib.parse.urlencode(params) or None
#      33     req = six.moves.urllib.request.Request(url, data=data, headers=headers)
# ---> 34     f = six.moves.urllib.request.urlopen(req)
#      35
#      36     text = f.read()
#
# /usr/local/Cellar/python/2.7.10/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /usr/local/Cellar/python/2.7.10/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     429             req = meth(req)
#     430
# --> 431         response = self._open(req, data)
#     432
#     433         # post-process response
#
# /usr/local/Cellar/python/2.7.10/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     447         protocol = req.get_type()
#     448         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 449                                   '_open', req)
#     450         if result:
#     451             return result
#
# /usr/local/Cellar/python/2.7.10/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     407             func = getattr(handler, meth_name)
#     408
# --> 409             result = func(*args)
#     410             if result is not None:
#     411                 return result
#
# /usr/local/Cellar/python/2.7.10/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in http_open(self, req)
#    1225
#    1226     def http_open(self, req):
# -> 1227         return self.do_open(httplib.HTTPConnection, req)
#    1228
#    1229     http_request = AbstractHTTPHandler.do_request_
#
# /usr/local/Cellar/python/2.7.10/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1198         else:
#    1199             try:
# -> 1200                 r = h.getresponse(buffering=True)
#    1201             except TypeError: # buffering kw not supported
#    1202                 r = h.getresponse()
#
# /usr/local/Cellar/python/2.7.10/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1130
#    1131         try:
# -> 1132             response.begin()
#    1133             assert response.will_close != _UNKNOWN
#    1134             self.__state = _CS_IDLE
#
# /usr/local/Cellar/python/2.7.10/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in begin(self)
#     451         # read until we get a non-100 response
#     452         while True:
# --> 453             version, status, reason = self._read_status()
#     454             if status != CONTINUE:
#     455                 break
#
# /usr/local/Cellar/python/2.7.10/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in _read_status(self)
#     407     def _read_status(self):
#     408         # Initialize with Simple-Response defaults
# --> 409         line = self.fp.readline(_MAXLINE + 1)
#     410         if len(line) > _MAXLINE:
#     411             raise LineTooLong("header line")
#
# /usr/local/Cellar/python/2.7.10/Frameworks/Python.framework/Versions/2.7/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Get hotels

# %%
sql = "Select EANHotelID,Name,LowRate,HighRate,StarRating,Latitude,Longitude,City " +\
      "From USproperties WHERE StateProvince='CA';"
hotels = DataFrame(psql.read_sql(sql, conn))

# %% [markdown]
# add crime data

# %%
hotels['Crime']=hotels.apply(lambda row: ViolentCrimeCount(lon=row.Longitude,
                                                               lat=row.Latitude,
                                                               radius=0.5), axis=1)

# %% [markdown]
# ## Create objects count for each cluster

# %%
from collections import Counter
col_names=list(unique(attractions.SubClassification))
col_names.append('ClusterNum')
col_names
clustersobjects_df=DataFrame(columns=col_names)

# %%
for index, row in clusters_df.iterrows():
    type_list=list((attractions[attractions.ClusterNum==row.ClusterNum])['SubClassification'])
    dc = dict(Counter( type_list ))
    dc['ClusterNum'] = row.ClusterNum
    clustersobjects_df=clustersobjects_df.append(dc,ignore_index=True)
clustersobjects_df=clustersobjects_df.fillna(0)

# %%
clustersobjects_df
print

# %% [markdown]
# ## Create commute time matrix
# Call Google directions API to get the commute time between the hotels and attraction clusters within the same city

# %%
def TransitTime(hotel_lat,hotel_lon,cluster_lat,cluster_lon):
    url="https://maps.googleapis.com/maps/api/directions/json?origin="+\
        str(hotel_lat)+","+str(hotel_lon)+\
        "&destination="+str(cluster_lat)+","+str(cluster_lon)+\
        "&mode=transit&key="+keys.google_key
    json_s=json.loads(scraperwiki.scrape(url))
    try:
        value_ret=json_s['routes'][0]['legs'][0]['duration']['value']
    except:
        value_ret=TransitTimeDrive(hotel_lat,hotel_lon,cluster_lat,cluster_lon)
    return value_ret

def TransitTimeDrive(hotel_lat,hotel_lon,cluster_lat,cluster_lon):
    url="https://maps.googleapis.com/maps/api/directions/json?origin="+\
        str(hotel_lat)+","+str(hotel_lon)+\
        "&destination="+str(cluster_lat)+","+str(cluster_lon)+\
        "&mode=driving&key="+keys.google_key
    json_s=json.loads(scraperwiki.scrape(url))
    try:
        value_ret=json_s['routes'][0]['legs'][0]['duration']['value']
    except:
        value_ret=0
    return value_ret*3

# %%
commutetime_df=DataFrame(columns=['EANHotelID','ClusterNum','CommuteTime','City'])

# %%
unique_cities=unique(hotels.City)
#cities_left=unique_cities[unique(hotels.City)>='San Diego']
cities_left=unique_cities
for city in cities_left:
    local_hotels=hotels[hotels.City==city]
    local_clusters=clusters_df[clusters_df.City==city]
    for index,hotel in local_hotels.iterrows():
        for index,cluster in local_clusters.iterrows():
            commute_t=TransitTime(hotel.Latitude,hotel.Longitude,cluster.Latitude,cluster.Longitude)
            commutetime_df=commutetime_df.append({'EANHotelID':hotel.EANHotelID,
                                                   'ClusterNum':cluster.ClusterNum,
                                                   'CommuteTime':commute_t,
                                                   'City':city},ignore_index=True)
    print city
# Out:
# Adelanto
# Agoura Hills
# Ahwahnee
# Alameda
# Alhambra
# Aliso Viejo
# Alpine
# Alturas
# Amador City
# American Canyon
# Anaheim
# Anderson
# Angels Camp
# Antioch
# Aptos
# Arcata
# Arnold
# Arroyo Grande
# Artesia
# Arvin
# Atascadero
# Auburn
# Avalon
# Avila Beach
# Azusa
# Bakersfield
# Baldwin Park
# Banning
# Barstow
# Bass Lake
# Beaumont
# Bell Gardens
# Bellflower
# Belmont
# Ben Lomond
# Benicia
# Berkeley
# Beverly Hills
# Big Bear City
# Big Bear Lake
# Big Sur
# Bishop
# Blue Lake
# Blythe
# Bodega Bay
# Borrego Springs
# Boulevard
# Brawley
# Brea
# Brentwood
# Bridgeport
# Brisbane
# Buellton
# Buena Park
# Burbank
# Burlingame
# Buttonwillow
# Cabazon
# Calabasas
# Calexico
# California City
# Calimesa
# Calistoga
# Victorville
# Visalia
# Vista
# Walnut
# Walnut Creek
# Warner Springs
# Wasco
# Watsonville
# Weed
# West Covina
# West Hollywood
# West Sacramento
# Westlake Village
# Westley
# Westminster
# Westmorland
# Whittier
# Williams
# Willits
# Willow Creek
# Willows
# Wilmington
# Windsor
# Winnetka
# Woodland
# Woodland Hills
# Yermo
# Yorba Linda
# Yosemite National Park
# Yountville
# Yreka
# Yuba City
# Yucca Valley
# ferndale

# %%
len(commutetime_df.index)
# Out:
# 31958

# %% [markdown]
# # Now let's put it all in a database

# %%
con = MySQLdb.connect(user="root", host="localhost",unix_socket="/tmp/mysql.sock")
cur = con.cursor()

# %%
cur.execute('CREATE DATABASE Illseeitall;')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-273-408309fd847e> in <module>()
# ----> 1 cur.execute('CREATE DATABASE Illseeitall;')
#
# /usr/local/lib/python2.7/site-packages/MySQL_python-1.2.5-py2.7-macosx-10.10-x86_64.egg/MySQLdb/cursors.pyc in execute(self, query, args)
#     203             del tb
#     204             self.messages.append((exc, value))
# --> 205             self.errorhandler(self, exc, value)
#     206         self._executed = query
#     207         if not self._defer_warnings: self._warning_check()
#
# /usr/local/lib/python2.7/site-packages/MySQL_python-1.2.5-py2.7-macosx-10.10-x86_64.egg/MySQLdb/connections.pyc in defaulterrorhandler(***failed resolving arguments***)
#      34     del cursor
#      35     del connection
# ---> 36     raise errorclass, errorvalue
#      37
#      38 re_numeric_part = re.compile(r"^(\d+)")
#
# ProgrammingError: (1007, "Can't create database 'Illseeitall'; database exists")

# %%
cur.execute('USE Illseeitall;')
# Out:
# 0L

# %%
attractions.to_sql(con=con, name='attractions', if_exists='replace', flavor='mysql',index=False)
clustersobjects_df.to_sql(con=con, name='clustersobjects', if_exists='replace', flavor='mysql',index=False)
hotels['Name'] =  hotels.Name.str.replace('[^\x00-\x7F]','')
hotels.to_sql(con=con, name='hotels', if_exists='replace', flavor='mysql',index=False)
clusters_df.to_sql(con=con, name='clusters', if_exists='replace', flavor='mysql',index=False)
commutetime_df.to_sql(con=con, name='commutetime', if_exists='replace', flavor='mysql',index=False)

# %%
cur.close()
con.close()

# %% [markdown]
# and, just to be safe, write as csv

# %%
commutetime_df.to_csv("commutetime_df.csv", sep=',',encoding='utf-8')
attractions.to_csv("attractions.csv", sep=',',encoding='utf-8')
clustersobjects_df.to_csv("clustersobjects_df.csv", sep=',',encoding='utf-8')
hotels.to_csv("hotels.csv", sep=',',encoding='utf-8')
clusters_df.to_csv("clusters_df.csv", sep=',',encoding='utf-8')

# %%
commutetime_df
# Out:
#        EANHotelID  ClusterNum  CommuteTime             City
# 0          418524          15          995         Adelanto
# 1          418524          16         2333         Adelanto
# 2          418524         537         8829         Adelanto
# 3          418524        1261         2122         Adelanto
# 4          474668          15          552         Adelanto
# 5          474668          16         2364         Adelanto
# 6          474668         537         8568         Adelanto
# 7          474668        1261         2315         Adelanto
# 8          269104          43         3208      Aliso Viejo
# 9          186417        1360         1002           Alpine
# 10         428079        1360           19           Alpine
# 11         307373          55         1236          Alturas
# 12         307373         113         1625          Alturas
# 13         336841          55          706          Alturas
# 14         336841         113         2065          Alturas
# 15         495594          55          573          Alturas
# 16         495594         113         2194          Alturas
# 17         323918          58          726      Amador City
# 18         226935         385         1044  American Canyon
# 19         248837         385         1092  American Canyon
# 20         308929         385         1158  American Canyon
# 21         105644          19         1444          Anaheim
# 22         105644          59         1431          Anaheim
# 23         105644          65          623          Anaheim
# 24         105644          70         1245          Anaheim
# 25         105644          72         5636          Anaheim
# 26         105644          73         1184          Anaheim
# 27         105644         335         5364          Anaheim
# 28         105644         469         2656          Anaheim
# 29         105644        1255         2516          Anaheim
# ...           ...         ...          ...              ...
# 31928      256122         432         1307            Yreka
# 31929      256122        1233          748            Yreka
# 31930      270655         432         2063            Yreka
# 31931      270655        1233         2097            Yreka
# 31932      355553         432         1415            Yreka
# 31933      355553        1233          655            Yreka
# 31934      461189         432          309            Yreka
# 31935      461189        1233         2000            Yreka
# 31936      495557         432         2295            Yreka
# 31937      495557        1233          622            Yreka
# 31938      138330         877         2157        Yuba City
# 31939      138330        1420         1036        Yuba City
# 31940      149705         877         1931        Yuba City
# 31941      149705        1420          472        Yuba City
# 31942      168988         877         2174        Yuba City
# 31943      168988        1420         1053        Yuba City
# 31944      176060         877         2375        Yuba City
# 31945      176060        1420          537        Yuba City
# 31946      188862         877         3021        Yuba City
# 31947      188862        1420          889        Yuba City
# 31948      205771         877           93        Yuba City
# 31949      205771        1420         3121        Yuba City
# 31950      245952         877         1746        Yuba City
# 31951      245952        1420          789        Yuba City
# 31952      338474         877         2044        Yuba City
# 31953      338474        1420          242        Yuba City
# 31954      201173         313         1208     Yucca Valley
# 31955      212294         313         1034     Yucca Valley
# 31956      222264         313         3351     Yucca Valley
# 31957      462503         313          781     Yucca Valley
#
# [31958 rows x 4 columns]

# %%
con = MySQLdb.connect(user="root", host="localhost",unix_socket="/tmp/mysql.sock")
cur = con.cursor()
cur.execute('USE Illseeitall;')
cur.execute('DROP TABLE attractions;')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-8d3128feb235> in <module>()
#       2 cur = con.cursor()
#       3 cur.execute('USE Illseeitall;')
# ----> 4 cur.execute('DROP TABLE attractions;')
#
# /usr/local/lib/python2.7/site-packages/MySQL_python-1.2.5-py2.7-macosx-10.10-x86_64.egg/MySQLdb/cursors.pyc in execute(self, query, args)
#     188         try:
#     189             r = None
# --> 190             r = self._query(query)
#     191         except TypeError, m:
#     192             if m.args[0] in ("not enough arguments for format string",
#
# KeyboardInterrupt:

# %%
attractions.to_sql(con=con, name='attractions', if_exists='replace', flavor='mysql',index=False)
# Out:
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 1
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 2
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 3
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 4
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 5
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 7
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 8
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 9
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 10
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 11
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 12
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 14
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 15
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 16
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 17
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 20
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 23
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 24
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 25
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 26
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 27
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 28
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 29
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 30
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 31
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 32
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 34
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 35
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 36
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 37
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 38
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 40
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 41
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 42
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 44
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 46
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 47
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 48
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 50
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 51
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 52
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 53
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 54
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 55
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 56
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 57
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 58
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 59
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 60
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 61
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 62
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 63
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 64
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 65
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 66
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 67
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 68
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 69
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 70
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 71
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 72
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 73
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 74
#   conn.executemany(self.insert_statement(), data_list)
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1357: Warning: Data truncated for column 'RegionNameLong' at row 75
#   conn.executemany(self.insert_statement(), data_list)

# %%
hotels['Name'] =  hotels.Name.str.replace('[^\x00-\x7F]','')
hotels.to_sql(con=con, name='hotels', if_exists='replace', flavor='mysql',index=False)

# %%
con = MySQLdb.connect(user="root", host="localhost",unix_socket="/tmp/mysql.sock")

# %%
cur = con.cursor()
cur.execute('USE Illseeitall;')
# Out:
# 0L

# %%
cur.execute('DROP TABLE attractions;')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-f3c1a1631958> in <module>()
# ----> 1 cur.execute('DROP TABLE attractions;')
#
# /usr/local/lib/python2.7/site-packages/MySQL_python-1.2.5-py2.7-macosx-10.10-x86_64.egg/MySQLdb/cursors.pyc in execute(self, query, args)
#     188         try:
#     189             r = None
# --> 190             r = self._query(query)
#     191         except TypeError, m:
#     192             if m.args[0] in ("not enough arguments for format string",
#
# KeyboardInterrupt:

# %%
attractions
# Out:
#       RegionID                                   RegionName  \
# 0      6239232                          20 Mule Team Museum
# 1      6162746                      20th Century Fox Studio
# 2      6200847                  29 Palms Historical Society
# 3      6065734                        555 California Street
# 4      6203149                           77 Geary Galleries
# 5      6263555                               A Noise Within
# 6      6151905                    Academy of Art University
# 7      6268825                             Adagio Galleries
# 8      6184976                      Adelanto Branch Library
# 9      6177513                Adelanto Chamber of Commerece
# 10     6193520                        Adobe Creek Golf Club
# 11     6240756                            Adobe Road Winery
# 12     6211697                               Adventure City
# 13     6327926                           Adventure Mountain
# 14     6328281                                  Aerial Tram
# 15     6327944                               Aerial Tramway
# 16     6063258                      African American Museum
# 17     6240473                                  Agate Beach
# 18     6209643                                Aggie Stadium
# 19     6161011                Agua Caliente Cultural Museum
# 20     6289761                                Ainsley House
# 21     6185663                                Alabama Hills
# 22     6144857                   Alameda County Fairgrounds
# 23     6065946                                 Alameda Park
# 24     6334515                                Alamere Falls
# 25     6005906                                 Alamo Square
# 26     6211835                        Albertina Wine Cellar
# 27     6134033               Albinger Archaeological Museum
# 28     6002556                              Alcatraz Island
# 29     6155590                               Alcove Theater
# ...        ...                                          ...
# 2871   6131959         Woodson Bridge State Recreation Area
# 2872   6069092                                Woodward Park
# 2873   6144083                          World Cruise Center
# 2874   6241515                           World Cup Ski Lift
# 2875   6172445               World Trade Center Los Angeles
# 2876   6292159  World's Biggest Dinosaurs-Cabazon Dinosaurs
# 2877   6328133                                 Wrath Winery
# 2878   6155649                               Xanadu Gallery
# 2879   6289491                           Yahoo Headquarters
# 2880   6177641              Yerba Buena Center for the Arts
# 2881   6069414   Yerba Buena Center for the Performing Arts
# 2882   6155653                          Yerba Buena Gardens
# 2883   6155656               Yerba Buena Ice Skating Center
# 2884   6201203                      Yolo County Fairgrounds
# 2885   6240595                          Yorba Regional Park
# 2886   6295211             Yosemite Arch Rock Gate Entrance
# 2887   6295207               Yosemite Big Oak Flat Entrance
# 2888   6089228                               Yosemite Falls
# 2889   6294970        Yosemite Mountain Sugar Pine Railroad
# 2890   6295012                      Yosemite Museum Gallery
# 2891   6241817                 Yosemite Tioga Pass Entrance
# 2892   6063468                              Yosemite Valley
# 2893   6294973                      Yosemite Visitor Center
# 2876 -116.773248         amusement 2015-09-17 08:54:45         276
# 2877 -121.920503            winery 2015-09-17 08:54:45         342
# 2878 -122.405850           museums 2015-09-17 08:54:45          10
# 2879 -122.026167         cityscape 2015-09-17 08:54:45         428
# 2880 -122.400873           museums 2015-09-17 08:54:45          10
# 2881 -122.401616           theater 2015-09-17 08:54:45          10
# 2882 -122.402985              park 2015-09-17 08:54:45          10
# 2883 -122.400420         amusement 2015-09-17 08:54:45          10
# 2884 -121.765553           stadium 2015-09-17 08:54:45         450
# 2885 -117.763280              park 2015-09-17 08:54:45        1414
# 2886 -119.730952              park 2015-09-17 08:54:45        1415
# 2887 -119.874552              park 2015-09-17 08:54:45        1416
# 2888 -119.597185              park 2015-09-17 08:54:45        1417
# 2889 -119.644824         amusement 2015-09-17 08:54:45        1418
# 2890 -119.588522           museums 2015-09-17 08:54:45        1417
# 2891 -119.257901              park 2015-09-17 08:54:45        1419
# 2892 -119.627552              park 2015-09-17 08:54:45         529
# 2893 -119.588518         cityscape 2015-09-17 08:54:45        1417
# 2894 -122.367799              park 2015-09-17 08:54:45         506
# 2895 -122.639180         cityscape 2015-09-17 08:54:45        1233
# 2896 -122.643719              park 2015-09-17 08:54:45        1233
# 2897 -121.632353          shopping 2015-09-17 08:54:45        1420
# 2898 -116.418612              park 2015-09-17 08:54:45         313
# 2899 -121.510388          monument 2015-09-17 08:54:45         298
# 2900 -118.823640             beach 2015-09-17 08:54:45         872
#
#                         City
# 0                      Boron
# 1                Los Angeles
# 2           Twentynine Palms
# 3              San Francisco
# 4              San Francisco
# 5                   Pasadena
# 6              San Francisco
# 7                Palm Desert
# 8                   Adelanto
# 9                   Adelanto
# 10                  Petaluma
# 11                  Petaluma
# 12                   Anaheim
# 13          South Lake Tahoe
# 14            Olympic Valley
# 15          South Lake Tahoe
# 16                   Oakland
# 17                 Mendocino
# 18                     Davis
# 19              Palm Springs
# 20                  Campbell
# 21                 Lone Pine
# 22                Pleasanton
# 23             Santa Barbara
# 24       Point Reyes Station
# 25             San Francisco
# 26                   Hopland
# 27                   Ventura
# 28             San Francisco
# 29             San Francisco
# ...                      ...
# 2871                 Corning
# 2872                  Fresno
# 2873               San Pedro
# 2874        South Lake Tahoe
# 2875             Los Angeles
# 2876                 Cabazon
# 2877                  Carmel
# 2878           San Francisco
# 2879               Sunnyvale
# 2880           San Francisco
# 2881           San Francisco
# 2882           San Francisco
# 2883           San Francisco
# 2884                Woodland
# 2885                 Anaheim
# 2886  Yosemite National Park
# 2887  Yosemite National Park
# 2888  Yosemite National Park
# 2889               Fish Camp
# 2890  Yosemite National Park
# 2891              Lee Vining
# 2892  Yosemite National Park
# 2893  Yosemite National Park
# 2894              Yountville
# 2895                   Yreka
# 2896                   Yreka
# 2897               Yuba City
# 2898            Yucca Valley
# 2899              Sacramento
# 2900                  Malibu
#
# [2901 rows x 9 columns]

# %%
unique([1,2,1,1,3])
# Out:
# array([1, 2, 3])

# %%
a=[1.088687,2445.23123]

# %%
str(a)
# Out:
# '[1.088687, 2445.23123]'

# %%
[str(round(i,0)) for i in a]
# Out:
# ['1.0', '2445.0']
